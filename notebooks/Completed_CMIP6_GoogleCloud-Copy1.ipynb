# %% [markdown]
# ### This notebook goes over how to access and load in CMIP6 data from the Google Cloud Storage (GCS), using full-depth ocean potential temperature model output from GFDL-ESM4.
#
# __Author__: Dr. Beadling. For any questions regarding the contents of this notebook please contact rebecca.beadling@temple.edu.

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr  # to read in Zarr format
import gcsfs # to read google cloud data
import momlevel as ml
import cftime
import cmocean

# %%
xr.set_options(display_style='html')
# %matplotlib inline                           
# %config InlineBackend.figure_format='retina' 
plt.rcParams['figure.figsize'] = 12,6

# %% [markdown]
# ### The CMIP6 data stored in the Google Cloud Storage are derived from the original CMIP6 data files distributed via the Earth System Grid Federation (ESGF) (https://esgf-node.llnl.gov/projects/cmip6/).The CMIP6 hosted on Google Cloud are maintained by the Climate Data Science Lab at Lamont Doherty Earth Observatory (LDEO) of Columbia University, as part of the Pangeo Project .
#
# ### The CMIP6 dataset in Google Cloud Storage is publically available and free to use.

# %% [markdown]
# ### The code below reads in a `.csv` file that contains the CMIP6 data catalog stored in the Google Cloud. We can read this in as a __Pandas DataFrame__.

# %%
google_cloud_cmip6 = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')

# %%
google_cloud_cmip6
# Out:
#        activity_id       institution_id      source_id       experiment_id  \
# 0       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 1       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 2       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 3       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 4       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# ...            ...                  ...            ...                 ...
# 523769        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 523770        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 523771        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 523772        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 523773        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
#
#        member_id table_id variable_id grid_label  \
# 0       r1i1p1f1     Amon          ps         gn
# 1       r1i1p1f1     Amon        rsds         gn
# 2       r1i1p1f1     Amon        rlus         gn
# 3       r1i1p1f1     Amon        rlds         gn
# 4       r1i1p1f1     Amon         psl         gn
# ...          ...      ...         ...        ...
# 523769  r1i1p1f1     Amon         tas         gr
# 523770  r1i1p1f1     Amon        tauu         gr
# 523771  r1i1p1f1     Amon         hur         gr
# 523772  r1i1p1f1     Amon         hus         gr
# 523773  r1i1p1f1     Amon        tauv         gr
#
#                                                    zstore  dcpp_init_year  \
# 0       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# 1       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# 2       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# 3       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# 4       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# ...                                                   ...             ...
# 523769  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 523770  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 523771  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 523772  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 523773  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
#
#          version
# 0       20170706
# 1       20170706
# 2       20170706
# 3       20170706
# 4       20170706
# ...          ...
# 523769  20211207
# 523770  20211207
# 523771  20211207
# 523772  20211207
# 523773  20211207
#
# [523774 rows x 11 columns]

# %% [markdown]
# ### The CMIP6 data on Google Cloud is organized by the following:
# * ### __activity_id__: The Model Intercomparison Project (MIP) activity. __CMIP__ is where the standard DECK experiments are (i.e., piControl, historical, 1pctCO2, etc). __ScenarioMIP__ is where the SSP scenario simulation output is.
# * ### __institution_id__: The name of the institution or modeling center where the model comes from. A list of institution_ids can be found [here](https://wcrp-cmip.github.io/CMIP6_CVs/docs/CMIP6_institution_id.html) (Make sure to show 500 entries!)
# * ### __source_id__: The name of the climate model. A table of all models participating in CMIP6 can be found [here](https://airtable.com/appYNLuWqAgzLbhSq/shrvRybShvNSE1Szp/tblC0DBPiCm7gjJqx).
# * ### __experiment_id__: The climate model experiment name.
# * ### __member_id__: The individual ensemble member.
# * ### __table_id__: Specifying realm (atmosphere, ocean, ice, land, etc) and frequency of output (hourly, daily, monthly, annual ... etc): Click [here](https://docs.google.com/spreadsheets/d/1Hmu9fE9GdXUZoTl90vDv-qiI803L2feMxe6dAR0oErI/edit#gid=110419801) for a list and description of of all the possible __table ids__.
# * ### __variable_id__: The name of the climate variables the models output. Some of these short names are very hard to discern unless you are very familiar with CMIP. Please see the table [here](https://docs.google.com/spreadsheets/d/1UUtoz6Ofyjlpx5LdqhKcwHFz2SGoTQV2_yekHyMfL9Y/edit#gid=1221485271) for all the possible variable names.
# * ### __grid_label__: a key indicating if the model output is on the model's native grid or if regridded.
# - grid_label = "gn" (output is reported on the native grid)
# - grid_label = "gr" (output is not reported on the native grid, but instead is regridded by the modeling group)
# - grid_label = “gm” (global mean output is reported, so data are not gridded)
#
#
# * ### __z_store__: The path to the Zarr store where the data is stored.

# %% [markdown]
# ### <span style="color:red"> Investigating the archive using the links above answer the following questions:
# ### <span style="color:red"> 1) How many individual climate models contributed simulations to CMIP6?
# ### <span style="color:red"> 2) If you wanted to analyze regridded monthly ocean _potential temperature_ ("sea water potential temperature") from the SSP5-85 simulation carried out by GFDL-ESM4, fill out the following information you would need:
#     activity_id:
#     institution_id:
#     source_id:
#     experiment_id: ssp585
#     member_id: r1i1p1f1
#     table_id:
#     variable_id:
#     grid_label:

# %%
#seleScenMIP_act_id = google_cloud_cmip6.sel(activity_id = "ScenarioMip")

# %% [markdown]
# 1. activity_id : ScenarioMip
# 2. institution_id: NOAA-GFDL
# 3. source_id: GFDL-ESM4
# 4. experiement_id : ssp585
# 5. member_id: rlilplfl - l's may be ones?
# 6. table_id: Omon
# 7. variable_id: thetao
# 8. grid_label : gr

# %% [markdown]
#  1.) Counting the number of ‘source id’s ‘ gives the number of models, and there are 131 listed for CMIP6. Each model has a number of experiments or simulations each ran, 4 of which are the required DECK experiments, 1 is the historical simulation. Another source (O’Neill, 2016) says that there were 23 individual MIP (model Intercomparison Projects) contributing to CMIP6, these are listed as the activity id’s. ScenarioMIP alone has 30 independent models contributing to it. So individual models around 131 and 23 separate mip’s.

# %% [markdown]
# 2.) The ssp5-85 simulation (of monthly ocean potential temperature) can be identified from the following categorization
#
# activity_id : ScenarioMip
# institution_id: NOAA-GFDL
# source_id: GFDL-ESM4
# experiement_id : ssp585
# member_id: rlilplfl - l's may be ones?
# table_id: Omon
# variable_id: thetao
# grid_l
#
# #seleScenMIP_act_id = google_cloud_cmip6.sel(activity_id = "ScenarioMip")abel : gr

# %% [markdown]
# ## We can use the information above and Pandas' `.query()` method to filter through the CMIP6 archive to load in the Dataset we need:

# %%
gfdl_esm4_thetao_data = google_cloud_cmip6.query(
    "activity_id=='ScenarioMIP' & \
    table_id == 'Omon' & \
    variable_id == 'thetao' & \
    experiment_id == 'ssp585' & \
    institution_id == 'NOAA-GFDL' &  \
    source_id == 'GFDL-ESM4' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)

# %%
gfdl_esm4_thetao_data
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 12095  ScenarioMIP      NOAA-GFDL  GFDL-ESM4        ssp585  r1i1p1f1     Omon
#
#       variable_id grid_label  \
# 12095      thetao         gr
#
#                                                   zstore  dcpp_init_year  \
# 12095  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
#
#         version
# 12095  20180701

# %% [markdown]
# ## Great, so now that we have the Dataset we want ... how do we load it in?? We can load in the Zarr store that we've isolated above using `gcsfs`, `zarr`, and `xarray`.

# %%
# this only needs to be created once per Jupyter session
gcs = gcsfs.GCSFileSystem(token='anon')

# %% [markdown]
# ## The code below retrieves the path to a specific zarr store (the first one from the dataframe above)

# %%
zstore_esm4_thetao = gfdl_esm4_thetao_data.zstore.values[-1]

# %%
zstore_esm4_thetao
# Out:
# 'gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ESM4/ssp585/r1i1p1f1/Omon/thetao/gr/v20180701/'

# %% [markdown]
# ## The code below creates a mutable-mapping-style interface to the zarra store and then loads in the Dataset using __xarray's__ `xr.open_zarr()` method. In the same line of code where we load in the Dataset we can also extract the array and rename some variables for consistency:

# %%
# create a mutable-mapping-style interface to the store
mapper_esm4_thetao = gcs.get_mapper(zstore_esm4_thetao)
# open the dataset using xarray and zarr
gfdl_esm4_thetao = xr.open_zarr(mapper_esm4_thetao, 
                                consolidated=True,use_cftime=True).thetao.rename({'lat':'latitude',
                                                             'lon':'longitude'})
gfdl_esm4_thetao
# Out:
# <xarray.DataArray 'thetao' (time: 1032, lev: 35, latitude: 180, longitude: 360)>
# dask.array<open_dataset-thetao, shape=(1032, 35, 180, 360), dtype=float32, chunksize=(13, 35, 180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lev        (lev) float64 2.5 10.0 20.0 32.5 ... 5e+03 5.5e+03 6e+03 6.5e+03
#   * longitude  (longitude) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#   * time       (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
# Attributes:
#     cell_measures:  area: areacello volume: volcello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     interp_method:  conserve_order1
#     long_name:      Sea Water Potential Temperature
#     original_name:  thetao
#     standard_name:  sea_water_potential_temperature
#     units:          degC

# %% [markdown]
# ## Take a moment to become acquainted with DataArray you've just loaded in. <span style="color:red"> How many dimensions are there? What are their names? What are their coordinate labels? Then, in the code below, write code that would produce a plot of sea surface temperature for the first time slice ('2015-01-16').

# %% [markdown]
# This is an array of the variable 'Sea Water Potential Temperature' (thetao)
# The dimensions of this DataArray include (4): latitude, longitude, time and lev. Lev is a depth term given in meters. It is also technically a pressure term, as depths for this simulation are given by a bearing from pressure reference. It appears that the unit for pressure is in x atm's (1vatm=14.7 psi). Lev may also just be the depth in meters, however 35 meters is not very deep so i'm thinking it is the pressure term where 35m is a pressure of 35xatm

# %%
#gfdl_esm4_thetao.sea_water_potential_temperature

# %%
time0=gfdl_esm4_thetao.isel(time=0)
time0
# Out:
# <xarray.DataArray 'thetao' (lev: 35, latitude: 180, longitude: 360)>
# dask.array<getitem, shape=(35, 180, 360), dtype=float32, chunksize=(35, 180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lev        (lev) float64 2.5 10.0 20.0 32.5 ... 5e+03 5.5e+03 6e+03 6.5e+03
#   * longitude  (longitude) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#     time       object 2015-01-16 12:00:00
# Attributes:
#     cell_measures:  area: areacello volume: volcello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     interp_method:  conserve_order1
#     long_name:      Sea Water Potential Temperature
#     original_name:  thetao
#     standard_name:  sea_water_potential_temperature
#     units:          degC

# %%
#time0.sel(lev=0, method ="nearest").plot(vmin=-2, vmax=32, cmap=cmocean.cm.thermal)

# %%
time0.sel(lev=2.5).plot(vmin=-2, vmax=32, cmap=cmocean.cm.thermal)

# %% [markdown]
# ## <span style="color:red"> Okay, now write code in the cell below that produces a time-average of the full-depth data spanning years 2015 to 2025 and a time-average of years 2081 to 2100 (**hint .... you've already done this in a previous project).

# %%
esm4_temp_15_25 = gfdl_esm4_thetao.sel(time=slice('2015-01-16','2025-12-16')).mean(dim='time')
esm4_temp_81_100 = gfdl_esm4_thetao.sel(time=slice('2081-01-16','2100-12-16')).mean(dim='time')
## do the same thing below but for the last 20 years.

# %% [markdown]
# ## <span style="color:red"> Okay, now compute the difference as last period minus first period:

# %%
difference_esm4 = esm4_temp_81_100 - esm4_temp_15_25

# %%
difference_esm4
# Out:
# <xarray.DataArray 'thetao' (lev: 35, latitude: 180, longitude: 360)>
# dask.array<sub, shape=(35, 180, 360), dtype=float32, chunksize=(35, 180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lev        (lev) float64 2.5 10.0 20.0 32.5 ... 5e+03 5.5e+03 6e+03 6.5e+03
#   * longitude  (longitude) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5

# %%
lev = difference_esm4.sel(lev=2.5)
lev.plot()

# %% [markdown]
# ### Examining your surface plot above tells you that our longitudes span 0 to 360, so if we want 24 W, this is equivalent to 360 - 24 = 336. <span style="color:red"> Knowing this, write code in the cell below that plots the difference in ocean temperature along longitude=336 using `.sel(longitude=336, method='nearest')` and using the cmocean.cm.balance colormap:

# %%
lon336_diff = difference_esm4.sel(longitude=336, method='nearest')
lon336_diff.plot.contourf(yincrease= False, vmin=-2, vmax=2, cmap=cmocean.cm.balance, levels=40)

# %% [markdown]
# ### <span style="color:red"> Repeat the steps above, but instead of plotting the temperature difference along a specific transect, plot the __full zonal average__.

# %%
difference_esm4.mean(dim="longitude").plot.contourf(yincrease= False, vmin=-2, vmax=2, cmap=cmocean.cm.balance, levels=40)

# %% [markdown]
# ### The following code produce a plot of the zonally-averaged ocean temperature over the first 20 years,  and the difference.

# %%
fig, (ax0,ax1) = plt.subplots(ncols=1,nrows=2,figsize=(10,10))

esm4_temp_15_25.mean(dim='longitude').plot.contourf(ax=ax0, yincrease=False,
                                                    levels=50, vmin=-2,vmax=30, cmap=cmocean.cm.thermal)

difference_esm4.mean(dim='longitude').plot.contourf(ax=ax1, yincrease=False,
                                                   vmin=-2,vmax=2,
                                                    levels=50, cmap=cmocean.cm.balance)

# %% [markdown]
# ### <span style="color:red"> In the cells below, describe how the zonally-averaged distribution of temperature changes from the end of the century relative to the start. Where does most of the heat uptake occur?

# %% [markdown]
# The zonally averaged distribution of temperature shown some patterns,some can be decribed based on expected heat radiance physical effects, for instance that there are the greatest increases in heat at the surface might be expected because of general ocean circulation's effects on heat distribution. In general there appears to be a pattern of greater heat gain happening to already warm bodies of water. This can be seen by comparing the two profiles, they have the same anomolous features and bodies present.
# There appears to be a symetry in heat gain/loss with respect to the equator , however there are deviations from this is probably due to differences in the northern and southern hemisphere's continent placements. Notable deviations occur however in a symmetric fashion at around 60 degrees North and South. In the Northern hemisphere these is heat loss from around 500m depth downwards. This is the greatest decrease in jeat thoughout the whole zonally averaged profile. This is probably due to the North Atlantic Deep Waters which form from the melting of the ice sheets, which may be expected around these latitudes, as they then travel south. This waer body tends to be more saline and of a higher temperature than those at the same depths in the southern hemisphere's counter part location.
# At around 40 degrees N and SOuth there is a body of water up to around 2,000 m depth which has experienced greater warming than the same depths towards the equation. This coud be due tp the general oceanic circulation patterns which create a more downwelling conditions? However this is near the horse laatirudes where the atmopshere has more high pressure systems, and the ocean's surface circulation can be quite still here. The breadth of these warming bodies appears to be of similar scale to the size of the gyres which have their centers here.
# At the surface to around 1,000 meters depth from latitudes greater/less than 70 N and South respectively, there is another difference in heat loss, where the southern hemisphere is experiencing loss and the Northern is experiencing gain. This probably has to do with the genereal ocean/continent masses and the resullting circulation at these locations. In the Arctic there exists more ocean and sea ice, which over the centurines has melted, decreasing the albedo of the surface and thus allowing more heat absorption from the sun, Arctic Amplification . In the Antarctic there is less of this effect because pf the circulation of the currents around the Antarctic ocean keeping that surface water body more isolated. Also this water tends to be a lower temperature in general and has less melting happening.

# %% [markdown]
# ### The following code is modified from above to now read in ssp245 data (medium emission scenario)

# %%
gfdl_esm4_thetao_data_ssp245 = google_cloud_cmip6.query(
    "activity_id=='ScenarioMIP' & \
    table_id == 'Omon' & \
    variable_id == 'thetao' & \
    experiment_id == 'ssp245' & \
    institution_id == 'NOAA-GFDL' &  \
    source_id == 'GFDL-ESM4' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)

zstore_esm4_thetao_ssp245 = gfdl_esm4_thetao_data_ssp245.zstore.values[-1]
# create a mutable-mapping-style interface to the store
mapper_esm4_thetao_ssp245 = gcs.get_mapper(zstore_esm4_thetao_ssp245)
# open the dataset using xarray and zarr
gfdl_esm4_thetao_ssp245 = xr.open_zarr(mapper_esm4_thetao_ssp245, 
                                consolidated=True,use_cftime=True).thetao.rename({'lat':'latitude',
                                                             'lon':'longitude'})
gfdl_esm4_thetao_ssp245
# Out:
# <xarray.DataArray 'thetao' (time: 1032, lev: 35, latitude: 180, longitude: 360)>
# dask.array<open_dataset-thetao, shape=(1032, 35, 180, 360), dtype=float32, chunksize=(13, 35, 180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lev        (lev) float64 2.5 10.0 20.0 32.5 ... 5e+03 5.5e+03 6e+03 6.5e+03
#   * longitude  (longitude) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#   * time       (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
# Attributes:
#     cell_measures:  area: areacello volume: volcello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     interp_method:  conserve_order1
#     long_name:      Sea Water Potential Temperature
#     original_name:  thetao
#     standard_name:  sea_water_potential_temperature
#     units:          degC

# %%
gfdl_esm4_thetao_data_ssp245
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 15154  ScenarioMIP      NOAA-GFDL  GFDL-ESM4        ssp245  r1i1p1f1     Omon
#
#       variable_id grid_label  \
# 15154      thetao         gr
#
#                                                   zstore  dcpp_init_year  \
# 15154  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
#
#         version
# 15154  20180701

# %%
# Create the time averages of the required tme spans

gfdl_esm4_thetao_ssp245
ssp245_esm4_temp_15_25 = gfdl_esm4_thetao_ssp245.sel(time=slice('2015-01-16','2025-12-16')).mean(dim='time')
ssp_245_esm4_temp_81_100 = gfdl_esm4_thetao_ssp245.sel(time=slice('2081-01-16','2100-12-16')).mean(dim='time')

# %%
Difference_ssp245 = esm4_temp_81_100 - esm4_temp_15_25
Difference_ssp245
# Out:
# <xarray.DataArray 'thetao' (lev: 35, latitude: 180, longitude: 360)>
# dask.array<sub, shape=(35, 180, 360), dtype=float32, chunksize=(35, 180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lev        (lev) float64 2.5 10.0 20.0 32.5 ... 5e+03 5.5e+03 6e+03 6.5e+03
#   * longitude  (longitude) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5

# %%
dif_surf_SSP245 = Difference_ssp245.sel(lev=2.5)
dif_surf_SSP245.plot()

# %%
ssp245_lon336_diff = Difference_ssp245.sel(longitude=336, method='nearest')
ssp245_lon336_diff.plot.contourf(yincrease= False, vmin=-2, vmax=2, cmap=cmocean.cm.balance, levels=40)

# %% [markdown]
# # Full Zonal Average Plot

# %% [markdown]
#  I chose the same scales after playing around with the max and min, this makes the plots from the
# Medium emission scenario comparable to the last one

# %%
fig, (ax0,ax1) = plt.subplots(ncols=1,nrows=2,figsize=(10,10))

ssp245_esm4_temp_15_25.mean(dim='longitude').plot.contourf(ax=ax0, yincrease=False,
                                                    levels=50, vmin=-2,vmax=30, cmap=cmocean.cm.thermal)

Difference_ssp245.mean(dim='longitude').plot.contourf(ax=ax1, yincrease=False,
                                                   vmin=-2,vmax=2,
                                                    levels=50, cmap=cmocean.cm.balance)

# %% [markdown]
# ### Repeat the excercise above:
# ### Compute the difference in zonally-averaged ocean temperature as the last-twenty year average minus the first. How does this differ to the plot you created above for the SSP585 scenario?

# %% [markdown]
# I used the same contour interval and color scheme with the same max and min's in order to make the plots more comparable. SSp585 represented the higher end of future emission scenarios. This makes the results make sense as the medium emission scenario showed overall less warming.
# Most of the general patterns appear in these maps, for instance that generally warmer bodies of water experienced greater warming, and the symmetries with respect to the equator. Most of the same anomolies exist, for instance the cold body of water around 60 degrees North. However the 'gyres' or warm water at around 40 degrees N and S up to around 2000 meters depth showed significantly less water. The bodies of water which showed an overall cooling in the high emiss scenario are present in this map as well and showed similar degree of cooling. In all the two maps show strikingly similar contours but with a smaller degree of warming in the medium emission scenario.
